# %%
import pandas as pd

flights = pd.read_csv('data/kaggle/flights_sample_10k.csv')
flights
# Out:
#          FL_DATE                AIRLINE                AIRLINE_DOT  \
# 0     2022-07-19  SkyWest Airlines Inc.  SkyWest Airlines Inc.: OO
# 1     2022-09-13       Republic Airline       Republic Airline: YX
# 2     2022-07-09  SkyWest Airlines Inc.  SkyWest Airlines Inc.: OO
# 3     2021-03-19  United Air Lines Inc.  United Air Lines Inc.: UA
# 4     2020-01-03  United Air Lines Inc.  United Air Lines Inc.: UA
# ...          ...                    ...                        ...
# 9995  2022-06-21              Envoy Air              Envoy Air: MQ
# 9996  2023-06-23  United Air Lines Inc.  United Air Lines Inc.: UA
# 9997  2022-02-07      PSA Airlines Inc.      PSA Airlines Inc.: OH
# 9998  2020-03-12        JetBlue Airways        JetBlue Airways: B6
# 9999  2021-03-14      Endeavor Air Inc.      Endeavor Air Inc.: 9E
#
#      AIRLINE_CODE  DOT_CODE  FL_NUMBER ORIGIN                     ORIGIN_CITY  \
# 0              OO     20304       3371    SAN                   San Diego, CA
# ...

# %%
flights.isna().value_counts()
# Out:
# FL_DATE  AIRLINE  AIRLINE_DOT  AIRLINE_CODE  DOT_CODE  FL_NUMBER  ORIGIN  ORIGIN_CITY  DEST   DEST_CITY  CRS_DEP_TIME  DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  WHEELS_ON  TAXI_IN  CRS_ARR_TIME  ARR_TIME  ARR_DELAY  CANCELLED  CANCELLATION_CODE  DIVERTED  CRS_ELAPSED_TIME  ELAPSED_TIME  AIR_TIME  DISTANCE  DELAY_DUE_CARRIER  DELAY_DUE_WEATHER  DELAY_DUE_NAS  DELAY_DUE_SECURITY  DELAY_DUE_LATE_AIRCRAFT
# False    False    False        False         False     False      False   False        False  False      False         False     False      False     False       False      False    False         False     False      False      True               False     False             False         False     False     True               True               True           True                True                       8002
# ...
